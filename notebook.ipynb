# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("builds/wave-function.dat")


# plt.plot(data["# x"], data["phi"])
# plt.
data = np.transpose(data)

plt.plot(data[0], data[1])
