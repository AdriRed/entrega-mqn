# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pot = np.loadtxt("builds/potential.dat")
energy_per_iter = np.loadtxt("builds/energy-per-iteration.dat")
wave_func = np.loadtxt("builds/wave-function.dat")
dens = np.loadtxt("builds/density.dat")

pot = np.transpose(pot)
energy_per_iter = np.transpose(energy_per_iter)
wave_func = np.transpose(wave_func)
dens = np.transpose(dens)

# %%
plt.plot(energy_per_iter[0], energy_per_iter[1])
